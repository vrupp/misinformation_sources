# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import twitter_functions as twf
import utils

import pandas as pd
import json
from tqdm import tqdm
from tqdm.contrib.concurrent import thread_map
import os
from os.path import join
from datetime import datetime, timedelta
import random
from copy import deepcopy

# %%
ACADEMIC = True
MAX_TWEETS = 500000
MAX_TWEETS_PER_QUERY = 100

domains = pd.read_csv("../resources/domains/clean/domain_list_clean.csv")["url"].unique()
twitter_dateformat = "%Y-%m-%dT%H:%M:%SZ"

params = {"granularity": "hour"}
if ACADEMIC:
    params["end_time"] = datetime(2021, 10, 1).strftime(twitter_dateformat)
    params["start_time"] = datetime(2021, 4, 1).strftime(twitter_dateformat)
else:
    params["end_time"] = (datetime.now() - timedelta(days=1)).strftime(twitter_dateformat)

with open("api-keys/jana.json") as f:
    api_keys = json.load(f)

data_dir = '../resources/twitter'
tweet_dst = join(data_dir, 'tweet-counts')
minimum_query = "lang:en -is:retweet"

config = {
    "bearer_token": api_keys["bearer-token"],
    "params": params
}

# %% [markdown]
# # Query Counts and Collect Parquet

# %%
i = 0
for url in tqdm(domains):
    config["params"]["query"] = f'{minimum_query} url:"{url}"'
    next_token = None
    while True:
        tweet_file_name = f"{i}.json"
        i += 1
        config["write_path"] = join(tweet_dst, tweet_file_name)

        twf.validate_config(config)

        json_response = twf.count_tweets(config, all=ACADEMIC, next_token=next_token)
        json_response["url"] = url
        with open(config["write_path"], "w") as f:
            json.dump(json_response, f)
        if 'meta' in json_response and 'next_token' in json_response['meta']:
            next_token = json_response['meta']['next_token']
        else:
            break

# %%
responses = []
for filename in os.listdir(tweet_dst):
    if not filename.startswith("error-"):
        with open(join(tweet_dst, filename)) as f:
            resp = json.load(f)
        if "data" in resp:
            responses.append(resp) 
tweet_counts = pd.DataFrame(responses).drop(columns="meta").explode("data", ignore_index=True)
tweet_counts = pd.concat([tweet_counts.drop(columns="data"), pd.DataFrame(tweet_counts["data"].values.tolist())], axis=1)
tweet_counts["start"] = pd.to_datetime(tweet_counts["start"])
tweet_counts["end"] = pd.to_datetime(tweet_counts["end"])
print(tweet_counts.shape)
tweet_counts.head()

# %%
tweet_counts.to_parquet(join(data_dir, "tweet-counts.parquet.gzip"), index=False, compression="gzip")

# %% [markdown]
# # Form Partitions of 500 (resp. 100) Tweets
# - Limitations:
#   - max. 1024 characters per query
#   - max. 500 (resp. 100) tweets per query
#   - max. 300 queries per 15 min.
#   - get equal data distribution regarding labels (accuracy, transparency, reliability)
# - Form sets of URL $U_1, \dots, U_n$, for $u_1, u_2, \dots \in U_i$
#   - $u_1, u_2, \dots$ share same accuracy and transparency score => Sets are distinct
#   - Query `lang:en -is:retweet (url:"u_1" OR url:"u_2" OR ...)` is max. 1024 character
# - Build timeranges
#   - Let $h_1, \dots, h_m$ be hourly timestamps, with $h_1$ = 2021-04-01 00:00 and $h_m$ = 2021-10-01 00:00
#   - Let $c(U_i, h_s, h_e)$ be the number of tweets for URLs $U_i$ in time range $[h_s, h_e)$
#   - For each $U_i$ form time frames $T_{i,j} = [h_s, h_e)$, s.t.
#     - $c(U_i, h_s, h_e) \geq 500$
#     - $c(U_i, h_s, h_{e-1}) < 500$
#     - "Smallest time frame containing at least 500 tweets"
# - A final query can be constructed using one $U_i$ and one $T_{i,j}$ and always returns 500 tweets

# %%
tweet_counts = pd.read_parquet(join(data_dir, "tweet-counts.parquet.gzip"))
domain_labels = pd.read_csv("../resources/domains/clean/domain_list_clean.csv")
tweet_counts = tweet_counts.merge(domain_labels, on="url")
print(tweet_counts.shape)
tweet_counts.head()
# Out:
# (43548109, 10)
#                   url                       end                     start  \
# 0  science.energy.gov 2021-05-30 01:00:00+00:00 2021-05-30 00:00:00+00:00
# 1  science.energy.gov 2021-05-30 02:00:00+00:00 2021-05-30 01:00:00+00:00
# 2  science.energy.gov 2021-05-30 03:00:00+00:00 2021-05-30 02:00:00+00:00
# 3  science.energy.gov 2021-05-30 04:00:00+00:00 2021-05-30 03:00:00+00:00
# 4  science.energy.gov 2021-05-30 05:00:00+00:00 2021-05-30 04:00:00+00:00
#
#    tweet_count        label                 source last_update  accuracy  \
# 0            0  pro science  media_bias_fact_check  2021-05-17         5
# 1            0  pro science  media_bias_fact_check  2021-05-17         5
# 2            0  pro science  media_bias_fact_check  2021-05-17         5
# 3            0  pro science  media_bias_fact_check  2021-05-17         5
# 4            0  pro science  media_bias_fact_check  2021-05-17         5
#
#    transparency      type
# 0             3  reliable
# 1             3  reliable
# 2             3  reliable
# 3             3  reliable
# 4             3  reliable

# %%
check_status_codes = False

if check_status_codes:
    status_codes = thread_map(utils.check_url_status, domain_labels["url"].unique(), max_workers=os.cpu_count() * 4)
    status_codes = pd.DataFrame(status_codes)
    status_codes.to_csv("../resources/domains/clean/domain_status_codes.csv", index=False)

# %%
status_codes = pd.read_csv("../resources/domains/clean/domain_status_codes.csv")
print(status_codes.shape, status_codes.query("status_code == 200").shape)
status_codes.head()
# Out:
# (9971, 4) (7957, 4)
#                              url                               full_url  \
# 0  notiziepericolose.blogspot.it  https://notiziepericolose.blogspot.it
# 1           ilmattoquotidiano.it           https://ilmattoquotidiano.it
# 2                 ilmessaggio.it                 https://ilmessaggio.it
# 3           ilfattoquotidaino.it            http://ilfattoquotidaino.it
# 4     ilquotidaino.wordpress.com     https://ilquotidaino.wordpress.com
#
#    status_code  redirected
# 0          200       False
# 1          200       False
# 2          200       False
# 3          200       False
# 4          200       False

# %%
# Filter by active URLs
tweet_counts = tweet_counts.merge(status_codes.query("status_code == 200")["url"], on="url")
tweet_counts.shape
# Out:
# (34767043, 10)

# %%
def to_query_str(urls):
    minimum_query = "lang:en -is:retweet"
    url_clause = " OR ".join([f'url:"{url}"' for url in urls])
    return f"{minimum_query} ({url_clause})"

def get_url_ranges(all_urls):
    url_ranges = [[all_urls[0]]]
    for url in all_urls[1:]:
        tmp_query = url_ranges[-1] + [url]
        query_str = to_query_str(tmp_query)
        if len(query_str) <= 1024:
            url_ranges[-1] = tmp_query
        else:
            url_ranges.append([url])
    return url_ranges

def get_hour_ranges(hour_counts):
    hour_counts = hour_counts.sort_index(ascending=False)
    hour_counts_cumsum = hour_counts.cumsum()
    hour_ranges = []
    end = hour_counts_cumsum.index[0][1]
    i = MAX_TWEETS_PER_QUERY
    while i <= hour_counts_cumsum[-1]:
        tmp = hour_counts_cumsum[hour_counts_cumsum >= i]
        start = tmp.index[0][0]
        hour_ranges.append((start, end))
        
        end = start
        i = tmp[0] + MAX_TWEETS_PER_QUERY
    return hour_ranges

# %%
partitions = []
url_counts = tweet_counts.set_index("url")
with tqdm(total=url_counts.index.unique().shape[0]) as pbar:
    for acc in range(1, 6):
        for trans in range(1, 4):
            tmp = tweet_counts.query(f"accuracy == {acc} & transparency == {trans}")
            if tmp.shape[0] > 0:
                ranges = []
                url_range = []
                count_sum = 0
                
                max_per_url = tmp.groupby("url")["tweet_count"].max().sort_values(ascending=False)
                urls = list(max_per_url.items())
                while len(urls) > 0:
                    pbar.update(1)

                    url, count = urls.pop(0)
                    url_range.append(url)
                    count_sum += count
                    if count_sum >= MAX_TWEETS_PER_QUERY or len(urls) == 0:
                        url_ranges = get_url_ranges(url_range)
                        for r in url_ranges:
                            hour_counts = url_counts.loc[r].groupby(["start", "end"])["tweet_count"].sum()
                            hour_ranges = get_hour_ranges(hour_counts)

                            # Only include URL ranges with min. MAX_TWEETS_PER_QUERY tweets
                            if len(hour_ranges) > 0:
                                hour_ranges = [(start.strftime(twitter_dateformat), end.strftime(twitter_dateformat)) for (start, end) in hour_ranges]
                                ranges.append({"url_range": r, "hour_ranges": hour_ranges})
                        
                        url_range = []
                        count_sum = 0

                partitions.append({
                    "accuracy": acc,
                    "transparency": trans,
                    "ranges": ranges
                })
# Out:
# 100%|██████████| 7924/7924 [24:04<00:00,  5.48it/s]

# %%
with open(join(data_dir, f"partitions-{MAX_TWEETS_PER_QUERY}.json"), "w") as f:
    json.dump(partitions, f)
print("accuracy", partitions[0]["accuracy"])
print("transparency", partitions[0]["transparency"])
print("ranges", partitions[0]["ranges"][0])
# Out:
# accuracy 1
# transparency 1
# ranges {'url_range': ['itv.com'], 'hour_ranges': [('2021-09-30T17:00:00Z', '2021-10-01T00:00:00Z'), ('2021-09-30T13:00:00Z', '2021-09-30T17:00:00Z'), ('2021-09-30T09:00:00Z', '2021-09-30T13:00:00Z'), ('2021-09-30T06:00:00Z', '2021-09-30T09:00:00Z'), ('2021-09-29T20:00:00Z', '2021-09-30T06:00:00Z'), ('2021-09-29T16:00:00Z', '2021-09-29T20:00:00Z'), ('2021-09-29T12:00:00Z', '2021-09-29T16:00:00Z'), ('2021-09-29T09:00:00Z', '2021-09-29T12:00:00Z'), ('2021-09-29T05:00:00Z', '2021-09-29T09:00:00Z'), ('2021-09-28T18:00:00Z', '2021-09-29T05:00:00Z'), ('2021-09-28T14:00:00Z', '2021-09-28T18:00:00Z'), ('2021-09-28T10:00:00Z', '2021-09-28T14:00:00Z'), ('2021-09-28T06:00:00Z', '2021-09-28T10:00:00Z'), ('2021-09-27T19:00:00Z', '2021-09-28T06:00:00Z'), ('2021-09-27T15:00:00Z', '2021-09-27T19:00:00Z'), ('2021-09-27T12:00:00Z', '2021-09-27T15:00:00Z'), ('2021-09-27T07:00:00Z', '2021-09-27T12:00:00Z'), ('2021-09-26T19:00:00Z', '2021-09-27T07:00:00Z'), ('2021-09-26T12:00:00Z', '2021-09-26T19:00:00Z'), ('2021-09-26T02:00:00Z', '2021-09-26T12:00:00Z'), ('2021-09-25T14:00:00Z', '2021-09-26T02:00:00Z'), ('2021-09-25T11:00:00Z', '2021-09-25T14:00:00Z'), ('2021-09-25T07:00:00Z', '2021-09-25T11:00:00Z'), ('2021-09-24T18:00:00Z', '2021-09-25T07:00:00Z'), ('2021-09-24T15:00:00Z', '2021-09-24T18:00:00Z'), ('2021-09-24T11:00:00Z', '2021-09-24T15:00:00Z'), ('2021-09-24T08:00:00Z', '2021-09-24T11:00:00Z'), ('2021-09-24T02:00:00Z', '2021-09-24T08:00:00Z'), ('2021-09-23T18:00:00Z', '2021-09-24T02:00:00Z'), ('2021-09-23T15:00:00Z', '2021-09-23T18:00:00Z'), ('2021-09-23T12:00:00Z', '2021-09-23T15:00:00Z'), ('2021-09-23T08:00:00Z', '2021-09-23T12:00:00Z'), ('2021-09-22T21:00:00Z', '2021-09-23T08:00:00Z'), ('2021-09-22T16:00:00Z', '2021-09-22T21:00:00Z'), ('2021-09-22T12:00:00Z', '2021-09-22T16:00:00Z'), ('2021-09-22T08:00:00Z', '2021-09-22T12:00:00Z'), ('2021-09-21T22:00:00Z', '2021-09-22T08:00:00Z'), ('2021-09-21T17:00:00Z', '2021-09-21T22:00:00Z'), ('2021-09-21T13:00:00Z', '2021-09-21T17:00:00Z'), ('2021-09-21T08:00:00Z', '2021-09-21T13:00:00Z'), ('2021-09-20T22:00:00Z', '2021-09-21T08:00:00Z'), ('2021-09-20T16:00:00Z', '2021-09-20T22:00:00Z'), ('2021-09-20T12:00:00Z', '2021-09-20T16:00:00Z'), ('2021-09-20T07:00:00Z', '2021-09-20T12:00:00Z'), ('2021-09-19T18:00:00Z', '2021-09-20T07:00:00Z'), ('2021-09-19T11:00:00Z', '2021-09-19T18:00:00Z'), ('2021-09-18T20:00:00Z', '2021-09-19T11:00:00Z'), ('2021-09-18T13:00:00Z', '2021-09-18T20:00:00Z'), ('2021-09-18T09:00:00Z', '2021-09-18T13:00:00Z'), ('2021-09-17T20:00:00Z', '2021-09-18T09:00:00Z'), ('2021-09-17T15:00:00Z', '2021-09-17T20:00:00Z'), ('2021-09-17T11:00:00Z', '2021-09-17T15:00:00Z'), ('2021-09-17T07:00:00Z', '2021-09-17T11:00:00Z'), ('2021-09-16T20:00:00Z', '2021-09-17T07:00:00Z'), ('2021-09-16T15:00:00Z', '2021-09-16T20:00:00Z'), ('2021-09-16T12:00:00Z', '2021-09-16T15:00:00Z'), ('2021-09-16T08:00:00Z', '2021-09-16T12:00:00Z'), ('2021-09-15T20:00:00Z', '2021-09-16T08:00:00Z'), ('2021-09-15T16:00:00Z', '2021-09-15T20:00:00Z'), ('2021-09-15T12:00:00Z', '2021-09-15T16:00:00Z'), ('2021-09-15T09:00:00Z', '2021-09-15T12:00:00Z'), ('2021-09-14T22:00:00Z', '2021-09-15T09:00:00Z'), ('2021-09-14T16:00:00Z', '2021-09-14T22:00:00Z'), ('2021-09-14T12:00:00Z', '2021-09-14T16:00:00Z'), ('2021-09-14T08:00:00Z', '2021-09-14T12:00:00Z'), ('2021-09-13T20:00:00Z', '2021-09-14T08:00:00Z'), ('2021-09-13T16:00:00Z', '2021-09-13T20:00:00Z'), ('2021-09-13T12:00:00Z', '2021-09-13T16:00:00Z'), ('2021-09-13T08:00:00Z', '2021-09-13T12:00:00Z'), ('2021-09-12T21:00:00Z', '2021-09-13T08:00:00Z'), ('2021-09-12T13:00:00Z', '2021-09-12T21:00:00Z'), ('2021-09-12T08:00:00Z', '2021-09-12T13:00:00Z'), ('2021-09-11T20:00:00Z', '2021-09-12T08:00:00Z'), ('2021-09-11T15:00:00Z', '2021-09-11T20:00:00Z'), ('2021-09-11T11:00:00Z', '2021-09-11T15:00:00Z'), ('2021-09-11T07:00:00Z', '2021-09-11T11:00:00Z'), ('2021-09-10T19:00:00Z', '2021-09-11T07:00:00Z'), ('2021-09-10T15:00:00Z', '2021-09-10T19:00:00Z'), ('2021-09-10T12:00:00Z', '2021-09-10T15:00:00Z'),  ...

# %% [markdown]
# # Create Query Sample

# %%
with open(join(data_dir, f"partitions-{MAX_TWEETS_PER_QUERY}.json")) as f:
    partitions = json.load(f)

# %%
sum([len(part["ranges"]) for part in partitions]) * 3
# Out:
# 3558

# %%
def sample_queries(partitions, random_state=19):
    random.seed(random_state)
    max_queries = MAX_TWEETS // MAX_TWEETS_PER_QUERY
    queries = []
    for part in deepcopy(partitions):
        i = 0

        # query each url range three times
        for r in part["ranges"]:
            for _ in range(3):
                if len(r["hour_ranges"]) == 0:
                    break
                
                k = random.randint(0, len(r["hour_ranges"]) - 1)
                time_range = r["hour_ranges"].pop(k)
                
                queries.append({
                    "accuracy": part["accuracy"],
                    "transparency": part["transparency"],
                    "urls": r["url_range"], 
                    "start": time_range[0], 
                    "end": time_range[1]
                })
                i += 1

        # add random ranges if available
        max_per_part = max_queries // len(partitions)
        while i < max_per_part and len(part["ranges"]) > 0:
            j = random.randint(0, len(part["ranges"]) - 1)
            r = part["ranges"][j]
            if len(r["hour_ranges"]) == 0:
                part["ranges"].pop(j)
                break

            k = random.randint(0, len(r["hour_ranges"]) - 1)
            time_range = r["hour_ranges"].pop(k)
            
            queries.append({
                "accuracy": part["accuracy"],
                "transparency": part["transparency"],
                "urls": r["url_range"], 
                "start": time_range[0], 
                "end": time_range[1]
            })
            i += 1
    
    return queries

queries = sample_queries(partitions)
print("#queries", len(queries))
print("#tweets", len(queries) * MAX_TWEETS_PER_QUERY)
# Out:
# #queries 4388
# #tweets 438800

# %%
with open(join(data_dir, f"queries-{MAX_TWEETS_PER_QUERY}.json"), "w") as f:
    json.dump(queries, f)

# %% [markdown]
# # Double Check Number of Tweets

# %%
with open(join(data_dir, f"queries-{MAX_TWEETS_PER_QUERY}.json")) as f:
    queries = json.load(f)
total_counts_per_url = tweet_counts.groupby("url")["tweet_count"].sum().rename("total_count")

# %%
def form_counts_subsets(queries):
    subsets = []
    url_counts = tweet_counts.set_index("url")
    for query in tqdm(queries):
        subset = url_counts

        subset = subset.loc[query["urls"]]
        subset = subset[(subset["start"] >= query["start"]) & (subset["end"] <= query["end"])]
        
        subsets.append(subset.reset_index())

    return subsets

counts_subsets = form_counts_subsets(queries)
# Out:
# 100%|██████████| 4388/4388 [1:02:09<00:00,  1.18it/s]

# %%
def count_tweets_per_query(queries, counts_subsets):
    counts = []
    for subset in tqdm(counts_subsets):
        counts.append(min(subset["tweet_count"].sum(), MAX_TWEETS_PER_QUERY))   # cap queries, which are larger than MAX_TWEETS_PER_QUERY
    
    query_df = pd.DataFrame(queries)
    query_df["type"] = query_df.apply(lambda row: "unreliable" if (row["accuracy"] <= 2 and row["transparency"] == 1) else "reliable", axis=1)
    query_df["tweet_count"] = counts
    return query_df

counts_per_query = count_tweets_per_query(queries, counts_subsets)
# Out:
# 100%|██████████| 4388/4388 [00:00<00:00, 5861.60it/s]

# %%
for group in ["accuracy", "transparency", "type"]:
    total_agg_counts = tweet_counts.groupby(group)["tweet_count"].sum().rename("total_count")
    agg_counts = counts_per_query.groupby(group)["tweet_count"].sum()
    print(pd.concat([agg_counts, total_agg_counts, (agg_counts / total_agg_counts).rename("ratio")], axis=1))
    print()
print("total number of tweets", counts_per_query["tweet_count"].sum())
# Out:
#           tweet_count  total_count     ratio
# accuracy
# 1              282900     88046435  0.003213
# 2               23500      1306546  0.017986
# 3               23300      3581294  0.006506
# 4               46600      8963308  0.005199
# 5               62500      5175351  0.012076
#
#               tweet_count  total_count     ratio
# transparency
# 1                  100200     15897080  0.006303
# 2                  141600     38010780  0.003725
# 3                  197000     53165074  0.003705
#
#             tweet_count  total_count     ratio
# type
# reliable         338600     91175854  0.003714
# unreliable       100200     15897080  0.006303
#
# total number of tweets 438800

# %%
assert counts_per_query["tweet_count"].sum() == (len(queries) * MAX_TWEETS_PER_QUERY)

# %%
def worst_case_url_distr(counts_subsets):
    counts = []
    for subset in tqdm(counts_subsets):
        subset = subset.sort_values(by=["end", "tweet_count"], ascending=False)
        
        count_cumsum = subset["tweet_count"].cumsum()
        i = count_cumsum[count_cumsum >= MAX_TWEETS_PER_QUERY].idxmin()
        counts.append(subset.loc[:i])  # .loc has inclusive bounds
    
    return pd.concat(counts).groupby("url")["tweet_count"].sum()

worst_case_per_url = worst_case_url_distr(counts_subsets)
# Out:
# 100%|██████████| 4388/4388 [00:14<00:00, 304.27it/s]

# %%
ratio = pd.concat([worst_case_per_url, total_counts_per_url, (worst_case_per_url / total_counts_per_url).fillna(1).rename("ratio")], axis=1)
ratio["tweet_count"].fillna(0, inplace=True)
ratio.query("total_count > 0 & tweet_count == 0").sort_values(by="total_count", ascending=False).to_records().tolist()
# Out:
# [('health.com', 0.0, 4889, 1.0),
#  ('panorama.it', 0.0, 2043, 0.0),
#  ('thetruthaboutcancer.com', 0.0, 1902, 0.0),
#  ('thechronicleherald.ca', 0.0, 1398, 0.0),
#  ('infiniteunknown.net', 0.0, 1270, 0.0),
#  ('yomiuri.co.jp', 0.0, 928, 0.0),
#  ('conservativeintel.com', 0.0, 825, 0.0),
#  ('parismatch.com', 0.0, 672, 0.0),
#  ('ourweekly.com', 0.0, 664, 0.0),
#  ('vosizneias.com', 0.0, 634, 0.0),
#  ('rfdtv.com', 0.0, 587, 0.0),
#  ('patriotfetch.com', 0.0, 578, 0.0),
#  ('officer.com', 0.0, 529, 1.0),
#  ('wschronicle.com', 0.0, 515, 0.0),
#  ('latribune.fr', 0.0, 473, 0.0),
#  ('decisiondeskhq.com', 0.0, 391, 0.0),
#  ('gazettes.com', 0.0, 369, 0.0),
#  ('watchtheyard.com', 0.0, 358, 0.0),
#  ('christiannews.net', 0.0, 344, 0.0),
#  ('world.wng.org', 0.0, 324, 0.0),
#  ('irresponsabile.com', 0.0, 297, 0.0),
#  ('orangeleader.com', 0.0, 286, 0.0),
#  ('homernews.com', 0.0, 266, 0.0),
#  ('thetimesweekly.com', 0.0, 265, 0.0),
#  ('albertapressleader.ca', 0.0, 265, 0.0),
#  ('journalistenwatch.com', 0.0, 244, 0.0),
#  ('kenfm.de', 0.0, 237, 0.0),
#  ('awarenessact.com', 0.0, 236, 0.0),
#  ('dunstabletoday.co.uk', 0.0, 236, 0.0),
#  ('bbc-news.us', 0.0, 231, 0.0),
#  ('cdn.espn.com', 0.0, 227, 0.0),
#  ('blackgenocide.org', 0.0, 224, 0.0),
#  ('bamapolitics.com', 0.0, 221, 0.0),
#  ('asian-voice.com', 0.0, 219, 0.0),
#  ('mytownneo.com', 0.0, 213, 0.0),
#  ('eastwoodadvertiser.co.uk', 0.0, 196, 0.0),
#  ('themichiganstar.com', 0.0, 196, 0.0),
#  ('thepeoplescube.com', 0.0, 180, 0.0),
#  ('thedestinlog.com', 0.0, 175, 0.0),
#  ('dailypress.net', 0.0, 169, 0.0),
#  ('physics.news', 0.0, 165, 0.0),
#  ('offthepress.com', 0.0, 163, 0.0),
#  ('climatism.blog', 0.0, 158, 0.0),
#  ('secretlifeofmom.com', 0.0, 151, 0.0),
#  ('herbs-info.com', 0.0, 149, 0.0),
#  ('freedomoutpost.com', 0.0, 130, 0.0),
#  ('silverstatetimes.com', 0.0, 130, 0.0),
#  ('rollingstone.de', 0.0, 128, 0.0),
#  ('colerainetimes.co.uk', 0.0, 119, 0.0),
#  ('libertyhub.com', 0.0, 114, 0.0),
#  ('fascism.news', 0.0, 112, 0.0),
#  ('insideover.com', 0.0, 111, 0.0),
#  ('promo.espn.com', 0.0, 110, 0.0),
#  ('thesciencepost.com', 0.0, 107, 0.0),
#  ('extra-times.com', 0.0, 107, 0.0),
#  ('ottawaherald.com', 0.0, 102, 0.0),
#  ('medias-presse.info', 0.0, 101, 0.0),
#  ('gmo.news', 0.0, 100, 0.0),
#  ('elkintribune.com', 0.0, 98, 0.0),
#  ('varesenews.it', 0.0, 97, 0.0),
#  ('censorship.news', 0.0, 96, 0.0),
#  ('newslanded.com', 0.0, 93, 0.0),
#  ('one-voice.fr', 0.0, 89, 0.0),
#  ('vaccinesafety.edu', 0.0, 89, 0.0),
#  ('metnews.com', 0.0, 86, 0.0),
#  ('rubikon.news', 0.0, 85, 0.0),
#  ('redhotconservative.com', 0.0, 79, 0.0),
#  ('libertybugle.com', 0.0, 78, 0.0),
#  ('cbs-news.us', 0.0, 76, 0.0),
#  ('breakingfirst.com', 0.0, 75, 0.0),
#  ('epnewsleader.com', 0.0, 71, 0.0),
#  ('c19pvpi.com', 0.0, 71, 0.0),
#  ('menrec.com', 0.0, 69, 0.0),
#  ('yadkinripple.com', 0.0, 68, 0.0),
#  ('hebdenbridgetimes.co.uk', 0.0, 67, 0.0),
#  ('portal24hs.com', 0.0, 66, 0.0),
#  ('ftleavenworthlamp.com', 0.0, 63, 0.0),
#  ('thecincinnatiherald.com', 0.0, 58, 0.0),
#  ('agjournalonline.com', 0.0, 54, 0.0),
#  ('insanity.news', 0.0, 53, 0.0),
#  ('newsinsideout.com', 0.0, 53, 0.0),
#  ('swp.de', 0.0, 51, 0.0),
#  ('weser-kurier.de', 0.0, 51, 0.0),
#  ('tricountyindependent.com', 0.0, 51, 0.0),
#  ('livesicilia.it', 0.0, 51, 0.0),
#  ('deception.news', 0.0, 51, 0.0),
#  ('wetherbynews.co.uk', 0.0, 51, 0.0),
#  ('cancerwisdom.net', 0.0, 49, 0.0),
#  ('fairborndailyherald.com', 0.0, 48, 0.0),
#  ('maineexaminer.com', 0.0, 46, 0.0),
#  ('suppressed.news', 0.0, 45, 0.0),
#  ('dallascitywire.com', 0.0, 44, 0.0),
#  ('qanon.app', 0.0, 44, 0.0),
#  ('elections.huffingtonpost.com', 0.0, 43, 1.0),
#  ('secondamendmentdaily.com', 0.0, 43, 0.0),
#  ('thetidewaternews.com', 0.0, 42, 0.0),
#  ('ifamericaknew.org', 0.0, 42, 0.0),
#  ('intellihub.com', 0.0, 42, 0.0),
#  ('ourdavie.com', 0.0, 40, 0.0),
#  ('faitsdivers.org', 0.0, 39, 0.0),
#  ('limesonline.com', 0.0, 39, 0.0),
#  ('revolutionpermanente.fr', 0.0, 39, 0.0),
#  ('burrardstreetjournal.com', 0.0, 38, 0.0),
#  ('dangerousmedicine.com', 0.0, 37, 0.0),
#  ('worldcantwait.net', 0.0, 37, 0.0),
#  ('vaccinejihad.com', 0.0, 36, 0.0),
#  ('wa.de', 0.0, 36, 0.0),
#  ('srpressgazette.com', 0.0, 35, 0.0),
#  ('politisite.com', 0.0, 35, 0.0),
#  ('komitid.fr', 0.0, 35, 0.0),
#  ('stevenscountytimes.com', 0.0, 33, 0.0),
#  ('patriote.info', 0.0, 32, 0.0),
#  ('counterjihad.com', 0.0, 30, 0.0),
#  ('coconutoil.com', 0.0, 30, 0.0),
#  ('ripleyandheanornews.co.uk', 0.0, 30, 0.0),
#  ('spenboroughguardian.co.uk', 0.0, 29, 0.0),
#  ('gucmakale.com', 0.0, 28, 1.0),
#  ('gardenstatetimes.com', 0.0, 28, 0.0),
#  ('mediafiledc.com', 0.0, 28, 0.0),
#  ('ripongazette.co.uk', 0.0, 28, 0.0),
#  ('c19bromhexine.com', 0.0, 28, 0.0),
#  ('platosguns.com', 0.0, 27, 0.0),
#  ('farmwars.info', 0.0, 27, 0.0),
#  ('todmordennews.co.uk', 0.0, 26, 0.0),
#  ('thedailydefender.com', 0.0, 26, 0.0),
#  ('neozone.org', 0.0, 26, 0.0),
#  ('vcij.org', 0.0, 25, 0.0),
#  ('notallowedto.com', 0.0, 25, 0.0),
#  ('mypalmbeachpost.com', 0.0, 25, 0.0),
#  ('tahiti-infos.com', 0.0, 25, 0.0),
#  ('thesuburbanite.com', 0.0, 24, 0.0),
#  ('atimes.com', 0.0, 23, 0.0),
#  ('nwzonline.de', 0.0, 23, 1.0),
#  ('extinction.news', 0.0, 23, 0.0),
#  ('sportsworld.nbcsports.com', 0.0, 23, 0.0),
#  ('giornaledibrescia.it', 0.0, 23, 0.0),
#  ('earthpulse.com', 0.0, 23, 0.0),
#  ('eunews.it', 0.0, 22, 0.0),
#  ('hemsworthandsouthelmsallexpress.co.uk', 0.0, 22, 0.0),
#  ('msg.news', 0.0, 21, 0.0),
#  ('chemotherapy.news', 0.0, 21, 0.0),
#  ('veneziatoday.it', 0.0, 20, 0.0),
#  ('southernchestercountyweeklies.com', 0.0, 20, 0.0),
#  ('bees.news', 0.0, 20, 0.0),
#  ('healing.news', 0.0, 20, 0.0),
#  ('blackandblondemedia.com', 0.0, 20, 1.0),
#  ('speech-point.com', 0.0, 19, 0.0),
#  ('qalerts.net', 0.0, 19, 0.0),
#  ('sciencedeception.com', 0.0, 19, 0.0),
#  ('middletowntranscript.com', 0.0, 19, 0.0),
#  ('herault-tribune.com', 0.0, 19, 0.0),
#  ('speech-point.net', 0.0, 19, 0.0),
#  ('shared.us', 0.0, 18, 0.0),
#  ('ksfy.com', 0.0, 18, 0.0),
#  ('scienzainrete.it', 0.0, 18, 0.0),
#  ('zentrum-der-gesundheit.de', 0.0, 18, 0.0),
#  ('thepiercecountytribune.com', 0.0, 18, 0.0),
#  ('rigged.news', 0.0, 18, 0.0),
#  ('silverbearcafe.com', 0.0, 17, 0.0),
#  ('wethepeoplefree.com', 0.0, 17, 0.0),
#  ('uslibertywire.com', 0.0, 16, 0.0),
#  ('mag24.es', 0.0, 16, 1.0),
#  ('jessaminejournal.com', 0.0, 16, 0.0),
#  ('politis.fr', 0.0, 16, 0.0),
#  ('alliedprogress.org', 0.0, 16, 0.0),
#  ('tatersgonnatate.com', 0.0, 16, 0.0),
#  ('dailybuzzlive.com', 0.0, 16, 0.0),
#  ('fusion.net', 0.0, 15, 1.0),
#  ('antifascistnews.net', 0.0, 15, 0.0),
#  ('kenbridgevictoriadispatch.com', 0.0, 15, 0.0),
#  ('edmontonexaminer.com', 0.0, 15, 0.0),
#  ('dailystarpost.com', 0.0, 15, 0.0),
#  ('departed.co', 0.0, 15, 0.0),
#  ('bugout.news', 0.0, 14, 1.0),
#  ('ef-magazin.de', 0.0, 14, 1.0),
#  ('essentialoils.news', 0.0, 14, 0.0),
#  ('brighouseecho.co.uk', 0.0, 14, 0.0),
#  ('thornegazette.co.uk', 0.0, 14, 0.0),
#  ('globalskywatch.com', 0.0, 14, 1.0),
#  ('hackthematrix.it', 0.0, 13, 0.0),
#  ('environ.news', 0.0, 13, 0.0),
#  ('bluelivesmatter.blue', 0.0, 13, 0.0),
#  ('factcheck.news', 0.0, 13, 1.0),
#  ('flake.news', 0.0, 13, 0.0),
#  ('pandora.tv', 0.0, 13, 1.0),
#  ('potatriotsunite.com', 0.0, 13, 0.0),
#  ('northtamatelegraph.com', 0.0, 12, 1.0),
#  ('antifawatch.news', 0.0, 12, 0.0),
#  ('chemo.news', 0.0, 12, 0.0),
#  ('londonwebnews.com', 0.0, 12, 0.0),
#  ('rapturenewsnetwork.com', 0.0, 12, 0.0),
#  ('abortions.news', 0.0, 12, 1.0),
#  ('react365.com', 0.0, 12, 0.0),
#  ('deutschlandkurier.de', 0.0, 12, 0.0),
#  ('resist.news', 0.0, 11, 0.0),
#  ('faked.news', 0.0, 10, 1.0),
#  ('lemondejuif.info', 0.0, 10, 0.0),
#  ('meridionews.it', 0.0, 10, 0.0),
#  ('nwherald.com', 0.0, 9, 1.0),
#  ('mystatesman.com', 0.0, 9, 1.0),
#  ('vaccinedeaths.com', 0.0, 9, 0.0),
#  ('100giornidaleoni.it', 0.0, 9, 1.0),
#  ('news-sentinel.com', 0.0, 9, 1.0),
#  ('observateurcontinental.fr', 0.0, 9, 1.0),
#  ('mywebtimes.com', 0.0, 9, 1.0),
#  ('zvw.de', 0.0, 9, 1.0),
#  ('fakepandemic.com', 0.0, 9, 0.0),
#  ('counterthink.com', 0.0, 9, 0.0),
#  ('fmobserver.com', 0.0, 9, 0.0),
#  ('berniepost.com', 0.0, 8, 1.0),
#  ('games.espn.com', 0.0, 8, 0.0),
#  ('alexanderhiggins.com', 0.0, 8, 0.0),
#  ('steubencourier.com', 0.0, 8, 0.0),
#  ('fasting.news', 0.0, 8, 0.0),
#  ('righterway.com', 0.0, 8, 0.0),
#  ('cnnsofake.news', 0.0, 8, 0.0),
#  ('magadailyreport.com', 0.0, 7, 0.0),
#  ('biggovernment.news', 0.0, 7, 0.0),
#  ('sweeteners.news', 0.0, 7, 0.0),
#  ('political-discussion.com', 0.0, 7, 1.0),
#  ('politicaltribune.org', 0.0, 7, 1.0),
#  ('molad.org', 0.0, 7, 0.0),
#  ('organicfarming.news', 0.0, 7, 0.0),
#  ('treason.news', 0.0, 7, 0.0),
#  ('dcstatesman.com', 0.0, 7, 0.0),
#  ('constitutionstatenews.com', 0.0, 6, 0.0),
#  ('wellbeingjournal.com', 0.0, 6, 0.0),
#  ('sanevax.org', 0.0, 6, 0.0),
#  ('falseflag.news', 0.0, 6, 0.0),
#  ('sunshinestatenews.com', 0.0, 6, 0.0),
#  ('chinesemedicine.news', 0.0, 6, 0.0),
#  ('norbaonline.it', 0.0, 6, 0.0),
#  ('cbds.news', 0.0, 6, 0.0),
#  ('nevadaiowajournal.com', 0.0, 6, 0.0),
#  ('nordic.businessinsider.com', 0.0, 5, 1.0),
#  ('thumbreporter.com', 0.0, 5, 0.0),
#  ('conservativeammo.com', 0.0, 5, 0.0),
#  ('factswt.com', 0.0, 5, 1.0),
#  ('luogocomune.net', 0.0, 5, 1.0),
#  ('cyberwar.news', 0.0, 5, 0.0),
#  ('ivg.net', 0.0, 5, 0.0),
#  ('newsomwatch.com', 0.0, 5, 1.0),
#  ('63red.com', 0.0, 5, 0.0),
#  ('lalucedimaria.it', 0.0, 5, 0.0),
#  ('secretnews.fr', 0.0, 5, 1.0),
#  ('nylive.me', 0.0, 5, 1.0),
#  ('nwtwincities.com', 0.0, 5, 0.0),
#  ('activistmommy.com', 0.0, 4, 1.0),
#  ('press.foxbusiness.com', 0.0, 4, 0.0),
#  ('hawkeyereporter.com', 0.0, 4, 0.0),
#  ('cronacaqui.it', 0.0, 4, 1.0),
#  ('ontarioproud.ca', 0.0, 4, 1.0),
#  ('breaking13news.com', 0.0, 4, 0.0),
#  ('tmzworldnews.com', 0.0, 4, 1.0),
#  ('powergrid.news', 0.0, 4, 1.0),
#  ('sonsoflibertyradio.com', 0.0, 4, 0.0),
#  ('medicalextremism.com', 0.0, 4, 0.0),
#  ('halturnershow.com', 0.0, 3, 0.0),
#  ('fourwinds10.net', 0.0, 3, 0.0),
#  ('fukushimawatch.com', 0.0, 3, 0.0),
#  ('confederacyofdrones.com', 0.0, 3, 0.0),
#  ('nortextimes.com', 0.0, 3, 1.0),
#  ('franchetvinfo.fr', 0.0, 3, 0.0),
#  ('newsmutiny.com', 0.0, 3, 0.0),
#  ('freepressfront.com', 0.0, 3, 0.0),
#  ('moronmajority.com', 0.0, 3, 0.0),
#  ('nrw-aktuell.tv', 0.0, 3, 0.0),
#  ('bullshitnews.org', 0.0, 3, 0.0),
#  ('christiannewsalerts.com', 0.0, 3, 0.0),
#  ('hollywoodhater.com', 0.0, 3, 0.0),
#  ('bioalaune.com', 0.0, 3, 0.0),
#  ('oilgeopolitics.net', 0.0, 3, 0.0),
#  ('eyehealth.news', 0.0, 3, 0.0),
#  ('mkecitywire.com', 0.0, 3, 1.0),
#  ('whitehousewatch.com', 0.0, 3, 1.0),
#  ('news4ktla.com', 0.0, 3, 0.0),
#  ('theleftcoaster.com', 0.0, 2, 1.0),
#  ('stuppid.com', 0.0, 2, 1.0),
#  ('top10grocerysecrets.com', 0.0, 2, 1.0),
#  ('tytnetwork.com', 0.0, 2, 1.0),
#  ('video.messaggeroveneto.gelocal.it', 0.0, 2, 1.0),
#  ('rawforbeauty.com', 0.0, 2, 1.0),
#  ('richmondleader.com', 0.0, 2, 1.0),
#  ('bulletsfirst.net', 0.0, 2, 1.0),
#  ('corrierediarezzo.corr.it', 0.0, 2, 1.0),
#  ('castelvetranoselinunte.it', 0.0, 2, 0.0),
#  ('facebook.com/thewashingtonstandard', 0.0, 2, 1.0),
#  ('aldf.com', 0.0, 2, 0.0),
#  ('lubbocktimes.com', 0.0, 2, 1.0),
#  ('lucisphilippines.press', 0.0, 2, 1.0),
#  ('aledotimesrecord.com', 0.0, 2, 0.0),
#  ('dottoremaeveroche.it', 0.0, 2, 0.0),
#  ('nycgazette.com', 0.0, 2, 1.0),
#  ('mediacircus.com', 0.0, 2, 1.0),
#  ('modernliberals.com', 0.0, 2, 1.0),
#  ('americauncensored.com', 0.0, 2, 0.0),
#  ('martiallaw.news', 0.0, 2, 1.0),
#  ('patriotpost.com', 0.0, 2, 0.0),
#  ('derfmagazine.com', 0.0, 2, 0.0),
#  ('threalnews.net', 0.0, 2, 0.0),
#  ('rpr1.de', 0.0, 2, 0.0),
#  ('mindcontrol.news', 0.0, 2, 0.0),
#  ('foodsupply.news', 0.0, 2, 0.0),
#  ('harddawn.com', 0.0, 2, 0.0),
#  ('mwcnews.net', 0.0, 2, 0.0),
#  ('skeptics.news', 0.0, 2, 0.0),
#  ('qanon.pub', 0.0, 2, 0.0),
#  ('radio6.fr', 0.0, 2, 0.0),
#  ('infosco.org', 0.0, 2, 0.0),
#  ('privacywatch.news', 0.0, 2, 0.0),
#  ('spacetourism.news', 0.0, 2, 0.0),
#  ('southernpatriotnews.com', 0.0, 2, 0.0),
#  ('atlbanana.com', 0.0, 1, 0.0),
#  ('misteriditalia.it', 0.0, 1, 1.0),
#  ('medicinenon.it', 0.0, 1, 0.0),
#  ('lynx.media', 0.0, 1, 0.0),
#  ('liberamenteservo.com', 0.0, 1, 0.0),
#  ('altleft.news', 0.0, 1, 0.0),
#  ('americanjournalreview.com', 0.0, 1, 0.0),
#  ('lakecountyjournal.com', 0.0, 1, 0.0),
#  ('monsantomafia.com', 0.0, 1, 1.0),
#  ('leveil.fr', 0.0, 1, 0.0),
#  ('sistertoldjah.com', 0.0, 1, 0.0),
#  ('newstrib.com', 0.0, 1, 1.0),
#  ('memoryholed.com', 0.0, 1, 0.0),
#  ('beto.news', 0.0, 1, 0.0),
#  ('runwonder.com', 0.0, 1, 0.0),
#  ('aikenstandard.com', 0.0, 1, 0.0),
#  ('offthemainpage.com', 0.0, 1, 1.0),
#  ('palmettostatenews.com', 0.0, 1, 1.0),
#  ('abc22now.com', 0.0, 1, 0.0),
#  ('onmeda.de', 0.0, 1, 0.0),
#  ('video.iltirreno.gelocal.it', 0.0, 1, 1.0),
#  ('oldnorthnews.com', 0.0, 1, 0.0),
#  ('topinfopost.com', 0.0, 1, 1.0),
#  ('toledoreporter.com', 0.0, 1, 1.0),
#  ('nutrients.news', 0.0, 1, 0.0),
#  ('thelivingspirits.net', 0.0, 1, 1.0),
#  ('superfood.news', 0.0, 1, 1.0),
#  ('silverstealers.net', 0.0, 1, 1.0),
#  ('regenere.org', 0.0, 1, 0.0),
#  ('saratogastandard.com', 0.0, 1, 1.0),
#  ('musicaeanima.com', 0.0, 1, 0.0),
#  ('morrisherald-news.com', 0.0, 1, 0.0),
#  ('michelesantoro.it', 0.0, 1, 0.0),
#  ('policestate.news', 0.0, 1, 1.0),
#  ('joeforamerica.com', 0.0, 1, 0.0),
#  ('mednat.news', 0.0, 1, 1.0),
#  ('duffleblog.com', 0.0, 1, 0.0),
#  ('inventions.news', 0.0, 1, 0.0),
#  ('centralgeorgianews.com', 0.0, 1, 0.0),
#  ('franbuzz.fr', 0.0, 1, 0.0),
#  ('actionnews3.com', 0.0, 1, 1.0),
#  ('thetrumpnewsgazette.com', 0.0, 1, 0.0),
#  ('thewashingtonsentinel.com', 0.0, 1, 0.0),
#  ('zeptha.com', 0.0, 1, 0.0),
#  ('ciponline.org', 0.0, 1, 0.0),
#  ('youthradio.org', 0.0, 1, 0.0),
#  ('thewildchild.co.za', 0.0, 1, 0.0),
#  ('filosofiaelogos.it', 0.0, 1, 0.0),
#  ('wwiii.news', 0.0, 1, 0.0),
#  ('conservative101.com', 0.0, 1, 0.0),
#  ('tinhtamvn.net', 0.0, 1, 0.0),
#  ('fightpp.org', 0.0, 1, 0.0),
#  ('eticamente.net', 0.0, 1, 0.0),
#  ('westnovanews.com', 0.0, 1, 0.0),
#  ('esthervillenews.net', 0.0, 1, 0.0),
#  ('enduringvision.com', 0.0, 1, 0.0),
#  ('wday.com', 0.0, 1, 0.0),
#  ('eastpeoriatimescourier.com', 0.0, 1, 0.0),
#  ('bients.com', 0.0, 1, 1.0),
#  ('celebrityreputation.com', 0.0, 1, 0.0),
#  ('veteransfordonaldtrump.com', 0.0, 1, 0.0),
#  ('thereporterz.com', 0.0, 1, 0.0),
#  ('internapoli.it', 0.0, 1, 0.0),
#  ('infostormer.com', 0.0, 1, 0.0),
#  ('stgeorgenews.com', 0.0, 1, 0.0),
#  ('supplementsreport.com', 0.0, 1, 0.0),
#  ('bizstandardnews.com', 0.0, 1, 0.0),
#  ('blackpigeonspeaks.com', 0.0, 1, 0.0),
#  ('borderlinez.com', 0.0, 1, 0.0),
#  ('infobattle.org', 0.0, 1, 0.0),
#  ('faithfamilyamerica.com', 0.0, 1, 1.0),
#  ('hillcountrychronicle.com', 0.0, 1, 0.0),
#  ('the-los-angeles-times.com', 0.0, 1, 0.0),
#  ('facebook.com/noncielodicono', 0.0, 1, 1.0),
#  ('grainoftruth.ca', 0.0, 1, 0.0),
#  ('goodfullness.com', 0.0, 1, 0.0),
#  ('thefakenewsgenerator.com', 0.0, 1, 0.0),
#  ('theminaretonline.org', 0.0, 1, 0.0),
#  ('canadafactcheck.ca', 0.0, 1, 1.0),
#  ('calltoactivism.com', 0.0, 1, 1.0),
#  ('bullionbullscanada.com', 0.0, 1, 1.0),
#  ('markzuckerberg.news', 0.0, 1, 1.0)]

# %%
(ratio["tweet_count"] > 0).sum(), (ratio["total_count"] > 0).sum(), ratio.shape[0], (ratio["tweet_count"] > 0).sum() / (ratio["total_count"] > 0).sum()
# Out:
# (5608, 6002, 7924, 0.9343552149283573)

# %%
tmp = tweet_counts.groupby("url")["tweet_count"].sum().sort_values(ascending=False).reset_index()
tmp["q"] = pd.qcut(tmp.index, q=10, labels=False)
tmp = tmp.merge(worst_case_per_url, on="url", how="left")
tmp[">0_all"] = tmp["tweet_count_x"] > 0
tmp[">0_counted"] = tmp["tweet_count_y"] > 0
tmp.groupby("q")[[">0_counted", ">0_all"]].sum()
# Out:
#    >0_counted  >0_all
# q
# 0         793     793
# 1         792     792
# 2         791     792
# 3         787     793
# 4         755     792
# 5         720     792
# 6         641     793
# 7         329     455
# 8           0       0
# 9           0       0
